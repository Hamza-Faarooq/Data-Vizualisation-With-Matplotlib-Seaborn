# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Plot
plt.plot(x, y, label='sin(x)')
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('Line Plot')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['A', 'B', 'C', 'D']
values = [4, 7, 1, 8]

# Plot
plt.bar(categories, values, color='skyblue')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.random.randn(1000)

# Plot
plt.hist(data, bins=30, color='lightgreen', edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
x = np.random.rand(50)
y = np.random.rand(50)
sizes = 1000 * np.random.rand(50)
colors = np.random.rand(50)

# Plot
plt.scatter(x, y, s=sizes, c=colors, alpha=0.5, cmap='viridis')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.random.randn(100)

# Plot
plt.boxplot(data)
plt.title('Box Plot')
plt.ylabel('Values')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

# Plot
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Pie Chart')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.random.rand(10, 10)

# Plot
plt.imshow(data, cmap='hot', interpolation='nearest')
plt.title('Heatmap')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample data
data = sns.load_dataset("iris")

# Plot
sns.pairplot(data, hue='species')
plt.title('Pair Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Sample data
data = np.random.randn(100)

# Plot
sns.violinplot(data=data)
plt.title('Violin Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.sin(x) + 0.5

# Plot
plt.fill_between(x, y1, color="skyblue", alpha=0.4)
plt.fill_between(x, y2, color="olive", alpha=0.4)
plt.title('Area Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
labels=np.array(['A', 'B', 'C', 'D'])
stats=np.array([4, 3, 2, 5])

# Plot
angles=np.linspace(0, 2*np.pi, len(labels), endpoint=False).tolist()
stats=np.concatenate((stats,[stats[0]]))
angles=np.concatenate((angles,[angles[0]]))

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.fill(angles, stats, color='blue', alpha=0.25)
ax.plot(angles, stats, color='blue', linewidth=2)
ax.set_yticklabels([])
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels)
plt.title('Radar Chart')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.array([100, -10, 15, -20, 25])

# Plot
fig, ax = plt.subplots()
x = np.arange(len(data))
cumulative = np.cumsum(data)
start = np.zeros_like(data)
start[1:] = cumulative[:-1]
for i, (value, start_point) in enumerate(zip(data, start)):
    ax.bar(x[i], value, bottom=start_point, edgecolor='black')

ax.axhline(0, color='black', linewidth=0.8)
plt.title('Waterfall Chart')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.random.randn(100)

# Plot
sns.boxplot(data=data)
plt.title('Box Plot')
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
labels = ['A', 'B', 'C', 'D']
sizes = [15, 30, 45, 10]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']

# Plot
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Pie Chart')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.random.rand(50)
y = np.random.rand(50)
sizes = 1000 * np.random.rand(50)
colors = np.random.rand(50)

# Plot
scatter = plt.scatter(x, y, s=sizes, c=colors, alpha=0.5, cmap='viridis')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
plt.colorbar(scatter)
plt.show()

# %%
import matplotlib.pyplot as plt
import squarify    # pip install squarify

# Sample data
sizes = [25, 30, 35, 10]

# Plot
squarify.plot(sizes=sizes, label=['A', 'B', 'C', 'D'], alpha=0.7)
plt.axis('off')
plt.title('Treemap')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
angles = np.linspace(0, 2 * np.pi, 50)
radii = np.abs(np.sin(angles))

# Plot
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(angles, radii)
ax.fill(angles, radii, color='skyblue', alpha=0.5)
plt.title('Polar Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
x = np.random.randn(1000)
y = np.random.randn(1000)

# Plot
plt.hexbin(x, y, gridsize=30, cmap='YlGnBu')
plt.colorbar()
plt.title('Hexbin Plot')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Sample data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis')
plt.title('3D Surface Plot')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset('tips')

# Plot
sns.jointplot(x='total_bill', y='tip', data=data, kind='hex', cmap='YlGnBu')
plt.title('Joint Plot')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sample data
data = sns.load_dataset('iris')
data = data.drop(columns='species')

# Plot
sns.clustermap(data, cmap='mako')
plt.title('Cluster Map')
plt.show()
